# %%
import pandas as pd
import seaborn as sns
import numpy as np
from scipy import stats
sns.set(palette='deep')
import matplotlib.pyplot as plt

# %%
A1 = '111921_BC20APR21A_WQX_All_di.csv'
df_A1 =pd.read_csv(A1, dtype=None)
df_A1
df_A1.keys()
# Out:
# Index(['Unnamed: 0', 'pH_1T', 'Unnamed: 0.1', 'Year',
#        'DOC_Loss(gC/day/m2)_Delineated_Average', 'Step',
#        'NH4_Loss(gN/day/m2)_Delineated_Average',
#        'Runoff_All(mm/day)_Delineated_Average',
#        'DON_Loss(gN/day/m2)_Delineated_Average',
#        'NO3_Loss(gN/day/m2)_Delineated_Average', 'DOC_mg/L',
#        'Sfc_Water_Temp_C', 'CO2', 'Alk_140', 'Condition', 'Criteria',
#        'DOC_Pool', 'NH4_Pool', 'NO3_Pool', 'Date'],
#       dtype='object')

# %%
df_A1
# Out:
#       Unnamed: 0  pH_1T  Unnamed: 0.1  Year  \
# 0           1309    8.5          1309  2001
# 1           1310    8.5          1310  2001
# 2           1311    8.5          1311  2001
# 3           1312    8.5          1312  2001
# 4           1313    8.5          1313  2001
# ...          ...    ...           ...   ...
# 1973        3282    8.5          3282  2006
# 1974        3283    8.5          3283  2006
# 1975        3284    8.5          3284  2006
# 1976        3285    8.5          3285  2006
# 1977        3286    8.5          3286  2006
#
#       DOC_Loss(gC/day/m2)_Delineated_Average  Step  \
# 0                                   0.001380  1309
# 1                                   0.001843  1310
# 2                                   0.002381  1311
# 3                                   0.001804  1312
# 4                                   0.001441  1313
# ...                                      ...   ...
# 1973                                0.011901  3282
# ...

# %%
B1 = '111921_BC20APR21B_WQX_All_di.csv'
df_B1 =pd.read_csv(B1, dtype=None)
df_B1
# Out:
#       Unnamed: 0  pH_1T  Unnamed: 0.1  DON_Loss(gN/day/m2)_Delineated_Average  \
# 0           1309    8.5          1309                                0.000018
# 1           1310    8.5          1310                                0.000024
# 2           1311    8.5          1311                                0.000031
# 3           1312    8.5          1312                                0.000023
# 4           1313    8.5          1313                                0.000019
# ...          ...    ...           ...                                     ...
# 1973        3282    8.5          3282                                0.000004
# 1974        3283    8.5          3283                                0.000004
# 1975        3284    8.5          3284                                0.000004
# 1976        3285    8.5          3285                                0.000004
# 1977        3286    8.5          3286                                0.000004
#
# ...

# %%
A2 = '111921_BC15OCT21F_WQX_All_di.csv'
df_A2 =pd.read_csv(A2, dtype=None)
df_A2
# Out:
#       Unnamed: 0  pH_1T  Unnamed: 0.1  DOC_Loss(gC/day/m2)_Delineated_Average  \
# 0           1309    8.5          1309                                0.000691
# 1           1310    8.5          1310                                0.000951
# 2           1311    8.5          1311                                0.001263
# 3           1312    8.5          1312                                0.000954
# 4           1313    8.5          1313                                0.000756
# ...          ...    ...           ...                                     ...
# 1973        3282    8.5          3282                                0.008759
# 1974        3283    8.5          3283                                0.008579
# 1975        3284    8.5          3284                                0.008407
# 1976        3285    8.5          3285                                0.008249
# 1977        3286    8.5          3286                                0.008106
#
# ...

# %%
B2 = '111921_BC08NOV21A_WQX_All_di.csv'
df_B2 =pd.read_csv(B2, dtype=None)
df_B2
# Out:
#       Unnamed: 0  pH_1T  Unnamed: 0.1  Year  \
# 0           1309    8.5          1309  2001
# 1           1310    8.5          1310  2001
# 2           1311    8.5          1311  2001
# 3           1312    8.5          1312  2001
# 4           1313    8.5          1313  2001
# ...          ...    ...           ...   ...
# 1973        3282    8.5          3282  2006
# 1974        3283    8.5          3283  2006
# 1975        3284    8.5          3284  2006
# 1976        3285    8.5          3285  2006
# 1977        3286    8.5          3286  2006
#
#       DON_Loss(gN/day/m2)_Delineated_Average  \
# 0                                   0.000009
# 1                                   0.000012
# 2                                   0.000016
# 3                                   0.000012
# 4                                   0.000010
# ...                                      ...
# 1973                                0.000003
# 1974                                0.000003
# ...

# %%
A3 = '111821_BC10NOV21A_WQX_All_di.csv'
df_A3=pd.read_csv(A3, dtype=None)
df_A3
# Out:
#       Unnamed: 0     pH_1T  Unnamed: 0.1  \
# 0           1309  8.500000          1309
# 1           1310  8.500000          1310
# 2           1311  8.500000          1311
# 3           1312  8.500000          1312
# 4           1313  8.500000          1313
# ...          ...       ...           ...
# 1973        3282  8.414770          3282
# 1974        3283  8.438245          3283
# 1975        3284  8.424267          3284
# 1976        3285  8.376897          3285
# 1977        3286  8.454376          3286
#
#       DON_Loss(gN/day/m2)_Delineated_Average  \
# 0                                   0.000009
# 1                                   0.000012
# 2                                   0.000016
# 3                                   0.000012
# 4                                   0.000010
# ...                                      ...
# 1973                                0.000005
# 1974                                0.000005
# 1975                                0.000005
# ...

# %%
B3 = '111921_BC15NOV21A_WQX_All_di.csv'
df_B3=pd.read_csv(B3, dtype=None)
df_B3
# Out:
#       Unnamed: 0  pH_1T  Unnamed: 0.1  NO3_Loss(gN/day/m2)_Delineated_Average  \
# 0           1309    8.5          1309                            9.611053e-08
# 1           1310    8.5          1310                            1.380026e-07
# 2           1311    8.5          1311                            1.859202e-07
# 3           1312    8.5          1312                            1.394651e-07
# 4           1313    8.5          1313                            1.088340e-07
# ...          ...    ...           ...                                     ...
# 1973        3282    8.5          3282                            1.099801e-07
# 1974        3283    8.5          3283                            1.078136e-07
# 1975        3284    8.5          3284                            1.057285e-07
# 1976        3285    8.5          3285                            1.037124e-07
# 1977        3286    8.5          3286                            1.018750e-07
#
# ...

# %%
qobs = 'S_BrushCreek_COMID_190641_NLDAS_mm__sfcrunoff_1992_2019.csv'
df_qobs =pd.read_csv(qobs, dtype=None)
print(df_qobs.head()); df_qobs.info()
# Out:
#        0
# 0  0.077
# 1  0.066
# 2  0.203
# 3  0.053
# 4  0.158
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10226 entries, 0 to 10225
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       10226 non-null  float64
# dtypes: float64(1)
# memory usage: 80.0 KB

# %%
#df_obs = pd.read_csv('BCSC0107_WQX.csv')
#df_obs

# %%
#df_bc_f = df_obs.loc[(df_obs['Location'] == 'Brush') & (df_obs['Yr'] < 2007)]; df_bc_f.info()

# %%
#df_bc_fqa = df_bc_f.drop(columns={'DOC', 'NO2', 'DTN', 'Location'}).fillna(method='ffill')
#df_bc_fqa.head()

# %%
#df_obs_exceed = pd.read_csv('Groundtruth_WQX_Exceedance_Observations.csv')
#df_obs_exceed.head()

# %%
file = '031221BC_GT_WQX_ALL.csv'
df_bc_fqa2 = pd.read_csv(file, parse_dates={"date": ['Date']}, keep_date_col=True,  dtype=None) 
df_bc_fqa2['Run'] = 'GT'
#df_bc_fqa2.keys()
df_bc_fqa2.drop(columns =['Location', 'Day', 'Month', 'Year', 'Discharge', 'Unnamed: 0']).head()
# Out:
#         date Condition  Temp   Sediment    pH  NH4   NO3  PO4    SO4  \
# 0 2001-08-06   Prefire   15.6     108.0  7.87  0.0  0.22  0.0  17.39
# 1 2001-09-27   Prefire   11.2       2.1  8.41  0.0  0.46  0.0  15.19
# 2 2001-10-25   Prefire    6.0       2.6  7.86  0.0  0.01  0.0  15.16
# 3 2001-11-30   Prefire    3.0       0.5  7.85  0.0  0.02  0.0  16.25
# 4 2002-01-08   Prefire    1.0      14.7  7.76  0.0  0.04  0.0  15.67
#
#    Runoff(mm_day)        Date Criteria Run
# 0        0.000000    8/6/2001    Meets  GT
# 1        0.000000   9/27/2001    Meets  GT
# 2        0.000000  10/25/2001    Meets  GT
# 3        0.000000  11/30/2001    Meets  GT
# 4        0.040719    1/8/2002    Meets  GT

# %%
#df_obs_exceed[((df_obs_exceed['Yr'] == df_bc_fqa2['date'].dt.year) & (df_obs_exceed['Mo'] == df_bc_fqa2['date'].dt.modf_bc_fqa2['date'].dt.year, df_bc_fqa2['date'].dt.month)
#df_bc_fqa2['date'].dt.month#, df_bc_fqa2['date'].dt.year})
#[((df_bc_fqa2['Date'] == df_obs_exceed['Mo']) & (df_bc_fqa2['Date']== df_obs_exceed['Yr']))]
#criteria_mask = df_di_a[((df_di_a['NH4_Pool'] > 0.569) & (df_di_a['pH_1T'] == 8.5) | ((df_di_a['NH4_Pool'] >  1.27) & (df_di_a['pH_1T'] == 8.0)) | (df_di_a['NO3_Pool'] > 1.59))];

# %%
#exceed_mask =df_obs_exceed[((df_obs_exceed['Yr'] == df_obs_exceed['Yr']) & (df_obs_exceed['Mo']== df_obs_exceed['Mo']))]
#df_di_a[((df_di_a['NH4_Pool'] > 0.569) & (df_di_a['pH_1T'] == 8.5)
#exceed_mask

# %%
#df_bc_fqa2['date'].dt.month == exceed_mask['Mo']
#df_di_a['Criteria'].loc[criteria_mask.index]

# %%
#df_bc_fqa2.drop(columns =['Location', 'Day', 'Month', 'Year', 'Unnamed: 0', 'Discharge'])

# %%
# Import KNeighborsClassifier from sklearn.neighbors
from sklearn.neighbors import KNeighborsClassifier 
# Create arrays for the features and the response variable
#y = df_bc_fqa['Discharge'].values
#X = df_.drop('party', axis=1).values

# %%
df_A1['Run'] =str('A1')
df_A2['Run'] =str('A2')
df_A3['Run'] =str('A3')
df_B1['Run'] =str('B1')
df_B2['Run'] =str('B2')
df_B3['Run'] =str('B3')
df_B3.head()
# Out:
# array(['Exceeds', 'Meets'], dtype=object)

# %%
#Concatinate all Velma Simulations into 1 df
df_VA_A = pd.concat([df_A1, df_A2, df_A3, df_B1, df_B2, df_B3])
df_VA_A
# Out:
#       Unnamed: 0  pH_1T  Unnamed: 0.1  Year  \
# 0           1309    8.5          1309  2001
# 1           1310    8.5          1310  2001
# 2           1311    8.5          1311  2001
# 3           1312    8.5          1312  2001
# 4           1313    8.5          1313  2001
# ...          ...    ...           ...   ...
# 1973        3282    8.5          3282  2006
# 1974        3283    8.5          3283  2006
# 1975        3284    8.5          3284  2006
# 1976        3285    8.5          3285  2006
# 1977        3286    8.5          3286  2006
#
#       DOC_Loss(gC/day/m2)_Delineated_Average  Step  \
# 0                                   0.001380  1309
# 1                                   0.001843  1310
# 2                                   0.002381  1311
# 3                                   0.001804  1312
# 4                                   0.001441  1313
# ...                                      ...   ...
# 1973                                0.000730  3282
# ...

# %%
#Editing the columns to fit with ground truth parameters 
df_VA_f = df_VA_A.rename(columns={'pH_1T':'pH', 'NO3_Loss(gN/day/m2)_Delineated_Average':'NO3_Loss',
       'NH4_Loss(gN/day/m2)_Delineated_Average':'NH4_Loss',
       'DON_Loss(gN/day/m2)_Delineated_Average':'DON_Loss',
       'Runoff_All(mm/day)_Delineated_Average':'Runoff(mm_day)',
       'DOC_Loss(gC/day/m2)_Delineated_Average':'DOC_Loss',
       'Sfc_Water_Temp_C':'Temp ', 'Date':'date', 'DOC_Pool': 'DOC', 'NH4_Pool': 'NH4', 'NO3_Pool':'NO3'}).drop(columns ={'Unnamed: 0.1'})
df_VA_f.head()
df_VA_f.keys()
# Out:
# Index(['Unnamed: 0', 'pH', 'Year', 'DOC_Loss', 'Step', 'NH4_Loss',
#        'Runoff(mm_day)', 'DON_Loss', 'NO3_Loss', 'DOC_mg/L', 'Temp ', 'CO2',
#        'Alk_140', 'Condition', 'Criteria', 'DOC', 'NH4', 'NO3', 'date', 'Run'],
#       dtype='object')

# %%
#Editing the groundtruth columns to fit with the VELMA parameters df
df_bc_u = df_bc_fqa2.drop(columns = {'Date', 'SO4', 'PO4', 'Month', 'Day', 'Discharge', 'Location'})
df_bc_u.head()
df_bc_u.index = pd.to_datetime(df_bc_u['date'])
df_bc_u.info()
df_bc_u['Criteria'].nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 55 entries, 2001-08-06 to 2006-11-02
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            55 non-null     datetime64[ns]
#  1   Unnamed: 0      55 non-null     int64
#  2   Year            55 non-null     int64
#  3   Condition       55 non-null     object
#  4   Temp            55 non-null     float64
#  5   Sediment        55 non-null     float64
#  6   pH              55 non-null     float64
#  7   NH4             55 non-null     float64
#  8   NO3             55 non-null     float64
#  9   Runoff(mm_day)  55 non-null     float64
#  10  Criteria        55 non-null     object
#  11  Run             55 non-null     object
# dtypes: datetime64[ns](1), float64(6), int64(2), object(3)
# memory usage: 5.6+ KB
# 2

# %%
#Tidying into 1 data frame
df_bc_all = pd.concat([df_VA_f, df_bc_u], sort=False)
df_bc_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11923 entries, 0 to 54
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      11923 non-null  int64
#  1   pH              11923 non-null  float64
#  2   Year            11923 non-null  int64
#  3   DOC_Loss        11868 non-null  float64
#  4   Step            11868 non-null  float64
#  5   NH4_Loss        11868 non-null  float64
#  6   Runoff(mm_day)  11923 non-null  float64
#  7   DON_Loss        11868 non-null  float64
#  8   NO3_Loss        11868 non-null  float64
#  9   DOC_mg/L        11868 non-null  float64
#  10  Temp            11923 non-null  float64
#  11  CO2             11868 non-null  float64
#  12  Alk_140         11868 non-null  float64
#  13  Condition       11923 non-null  object
#  14  Criteria        11923 non-null  object
#  15  DOC             11868 non-null  float64
#  16  NH4             11923 non-null  float64
# ...

# %%
df_bc_all_f = df_bc_all.drop(columns = ['Unnamed: 0', 'Year', 'DOC_Loss', 'Step', 'NH4_Loss',
                          'DON_Loss', 'NO3_Loss', 'CO2', 'Alk_140',
                          'DOC','Sediment'])
df_bc_all_f.index = pd.to_datetime(df_bc_all_f['date'])
df_bc_all_f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 11923 entries, 2001-08-02 to 2006-11-02
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   pH              11923 non-null  float64
#  1   Runoff(mm_day)  11923 non-null  float64
#  2   DOC_mg/L        11868 non-null  float64
#  3   Temp            11923 non-null  float64
#  4   Condition       11923 non-null  object
#  5   Criteria        11923 non-null  object
#  6   NH4             11923 non-null  float64
#  7   NO3             11923 non-null  float64
#  8   date            11923 non-null  object
#  9   Run             11923 non-null  object
# dtypes: float64(6), object(4)
# memory usage: 1.0+ MB

# %%
df_bc_all.keys()
# Out:
# Index(['Unnamed: 0', 'pH', 'Year', 'DOC_Loss', 'Step', 'NH4_Loss',
#        'Runoff(mm_day)', 'DON_Loss', 'NO3_Loss', 'DOC_mg/L', 'Temp ', 'CO2',
#        'Alk_140', 'Condition', 'Criteria', 'DOC', 'NH4', 'NO3', 'date', 'Run',
#        'Sediment'],
#       dtype='object')

# %%
ax = sns.boxenplot(data=df_bc_all_f.rename(columns={'DOC_mg/L':'DOC (mg/L)', 'Temp ': 'Sfc W Temp (C)', 'NH4': 'NH4 (mg/L)', 'NO3': 'NO3 (mg/L)'}), orient="h", palette="Set2")
#ax.set_axis_labels(y_var='BC WQX Parameters')
#ax.set_xticklabels(labels = (np.linspace[-10:35]), step=5)

# %%
ax = sns.violinplot(data=df_bc_all_f, orient="v", palette="Set2")

# %%
g = sns.catplot(data=df_bc_all_f, kind= 'boxen', hue='Criteria', x=df_bc_all_f.columns(), y=df_bc_all_f.max())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-203-46a7ce4173cd> in <module>
# ----> 1 g = sns.catplot(data=df_bc_all_f, kind= 'boxen', hue='Criteria', x=df_bc_all_f.columns(), y=df_bc_all_f.max())
#
# TypeError: 'Index' object is not callable

# %%
g = sns.catplot(data=df_bc_u.drop(columns =['Sediment', 'Run', 'Year', 'Unnamed: 0']
                                    ), kind= 'boxen')

# %%
ax= sns.boxenplot(data=df_bc_u.drop(columns =['Sediment', 'Run', 'Year', 'Unnamed: 0']),  hue='Condition', x='Criteria', y='NO3')

# %%
ax= sns.boxenplot(data=df_bc_u.drop(columns =['Sediment', 'Run', 'Year', 'Unnamed: 0']),  hue='Criteria', x='Condition', y='NH4')

# %%
ax= sns.boxenplot(data=df_bc_u.drop(columns =['Sediment', 'Run', 'Year', 'Unnamed: 0']))

# %%
#df_bc_fqa2.drop(columns =['Sediment', 'Run', 'Location', 'Day', 'Month', 'Year', 'Unnamed: 0', 'Discharge']
                                    ).info()

# %%
#df_bc_f.info()

# %%
ax = sns.boxenplot(x='Condition', y='Runoff(mm_day)', data=df_bc_all_f)
#ax = sns.violinplot(x='Condition', y='NO3', data=df_bc_fqa2, size=1.25)

plt.show()

# %%
ax = sns.violinplot(x='Condition', y='NH4', data=df_bc_all_f, size=1.25)

# %%
fig1 = sns.boxenplot(x='Criteria', y='NH4', data=df_bc_all_f, hue='Run')
#fig1.set_axis_labels(y_var='NH4 (mg/L)')
#plt.show()

fig5 = sns.catplot(data=df_bc_all_f, kind='boxen', x= 'Criteria',
            y='NH4',
            hue='Run')
fig5.set_axis_labels(y_var=' NH4 (mg/L)')

fig6 = sns.catplot(data=df_bc_all_f, kind='boxen', x= 'Criteria',
            y='NO3',
            hue='Run')
fig6.set_axis_labels(y_var=' NO3 (mg/L)')

fig7 = sns.catplot(data=df_bc_all_f, kind='boxen', x= 'Run',
            y='NH4',
            hue='Condition')
fig7.set_axis_labels(y_var=' NH4 (mg/L)')

fig8 = sns.catplot(data=df_bc_all_f, kind='boxen', x= 'Run',
            y='NO3',
            hue='Condition')
fig8.set_axis_labels(y_var=' NO3 (mg/L)')

fig9 = sns.catplot(data=df_bc_all_f, kind='boxen', x= 'Run',
            y='DOC_mg/L',
            hue='Condition', showfliers=False)
fig9.set_axis_labels(y_var='DOC (mg/L)')

fig10 = sns.catplot(data=df_bc_all_f, kind='boxen', x= 'Run',
            y='NH4',
            hue='Condition')
fig10.set_axis_labels(y_var='NH4 (mg/L)')

fig11 = sns.catplot(data=df_bc_all_f, kind='boxen', x= 'Run',
            y='pH',
            hue='Condition')
fig11.set_axis_labels(y_var='pH')

fig11 = sns.catplot(data=df_bc_all_f, kind='boxen', x= 'Condition',
            y='pH',
            hue='Run')
fig11.set_axis_labels(y_var='pH')


#ax = sns.boxenplot(x='Criteria', y='pH', data=df_bc_all_f, hue='Run')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-246-24c093e672eb> in <module>
#      43 fig11.set_axis_labels(y_var='pH')
#      44
# ---> 45 fig12 = sns.catplot(x=df_bc_all_f.index.month, y='Runoff(mm_day)', data= df_bc_all_f,hue = "Criteria", showfliers=False)
#      46 fig12.set_axis_labels(v_var='Month')
#      47 #ax = sns.boxenplot(x='Criteria', y='pH', data=df_bc_all_f, hue='Run')
#
# ~\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
#df_VA_A.keys()
ax= sns.violinplot(data=df_bc_all_f, hue='Condition', x='Run', y='NH4')

# %%
ax= sns.boxenplot(data=df_bc_all_f, hue='Condition', x='Run', y='NO3')

# %%
#df_VA_A.keys()
ax= sns.boxenplot(data=df_bc_all_f, hue='Condition', x='Run', y='DOC_mg/L', showfliers=False)

# %%
df_VA_A.keys()
ax= sns.violinplot(data=df_bc_all_f, hue='Criteria', x='Run', y='NH4', hue_order={'Meets', 'Exceeds'})

# %%
#df_VA_A.keys()
ax= sns.violinplot(data=df_bc_all_f, hue='Criteria', x='Run', y='NO3', hue_order={'Meets', 'Exceeds'})

# %%
ax= sns.boxenplot(data=df_bc_all_f, hue='Criteria', x='Run', y='DOC_mg/L',showfliers=False, hue_order={'Meets', 'Exceeds'})

# %%
df_VA_A.keys()
ax= sns.violinplot(data=df_bc_all_f, hue='Run', x='Condition', y='NH4')

# %%
ax = sns.boxenplot(x='Condition', y='NH4', data=df_bc_all_f, hue='Run')

# %%
ax = sns.boxenplot(x='Condition', y='NO3', data=df_bc_all_f, hue='Run')

# %%
ax = sns.violinplot(x='Criteria', y='NO3', data=df_bc_all_f, hue='Run')

# %%
ax = sns.violinplot(x='Condition', y='NO3', data=df_bc_all_f, hue='Run')

# %%
ax = sns.boxenplot(x='Condition', y='NO3', data=df_bc_all_f, hue='Run')

# %%
ax = sns.boxenplot(x='Criteria', y='DOC_mg/L', data=df_bc_all_f, hue='Run', showfliers=False)

# %%
ax = sns.boxenplot(x='Condition', y='DOC_mg/L', data=df_bc_all_f, hue='Run', showfliers=False)

# %%
ax = sns.boxenplot(x='Criteria', y='pH', data=df_bc_all_f, hue='Run')

# %%
ax = sns.boxenplot(x='Condition', y='pH', data=df_bc_all_f, hue='Run')

# %%
ax = sns.boxenplot(x='Criteria', y='Runoff(mm_day)', data=df_bc_all_f, hue='Run')

# %%
ax = sns.boxenplot(x='Criteria', y='Runoff(mm_day)', data=df_bc_all_f, hue='Run', showfliers=False)

# %%
ax = sns.boxenplot(x='Condition', y='Runoff(mm_day)', data=df_bc_all_f, hue='Run', showfliers=False)

# %%
df_bc_all_f.groupby(by=[df_bc_all_f.index.month]).describe()

#ax = sns.boxenplot(x='Condition', y='Runoff(mm_day)', data=df_bc_all_f, hue='Run', showfliers=False)
# Out:
#           pH                                                         \
#        count      mean       std       min       25%  50%  75%  max
# date
# 1      934.0  8.493126  0.050400  7.730000  8.500000  8.5  8.5  8.5
# 2      851.0  8.468387  0.113421  7.796143  8.500000  8.5  8.5  8.5
# 3      933.0  8.443613  0.171503  6.953971  8.500000  8.5  8.5  8.5
# 4      905.0  8.370953  0.267023  7.085042  8.417616  8.5  8.5  8.5
# 5      933.0  8.323904  0.314884  6.947459  8.269035  8.5  8.5  8.5
# 6      904.0  8.370672  0.252183  7.221326  8.343012  8.5  8.5  8.5
# 7      936.0  8.279752  0.385142  5.738487  8.179301  8.5  8.5  8.5
# 8     1117.0  8.320392  0.326831  6.765151  8.250592  8.5  8.5  8.5
# 9     1084.0  8.404058  0.222947  7.150681  8.500000  8.5  8.5  8.5
# 10    1121.0  8.421654  0.192793  7.386986  8.500000  8.5  8.5  8.5
# 11    1085.0  8.445634  0.163263  7.383913  8.500000  8.5  8.5  8.5
# 12    1120.0  8.474717  0.091644  7.703715  8.500000  8.5  8.5  8.5
#
# ...

# %%
ax = sns.boxplot(x=df_bc_all_f.index.month, y='Runoff(mm_day)', data= df_bc_all_f, hue = "Criteria",  hue_order = {'Meets', 'Exceeds'}, showfliers=False)
#fig12.set_axis_labels(v_var='Month')
#fig12 = sns.catplot(data=df_bc_all_f.index.month, kind='boxen', x= 'Condition',
           # y='Runoff(mm_day)', hue = 'Criteria', showfliers=False)

# %%
ax = sns.boxplot(x=df_bc_all_f.index.month, y='Runoff(mm_day)', data= df_bc_all_f,hue = "Condition", showfliers=False)

# %%
ax = sns.boxplot(x=df_bc_all_f.index.year, y='Runoff(mm_day)', data= df_bc_all_f,hue = "Criteria", hue_order={'Meets', 'Exceeds'}, showfliers=False)

# %%
ax = sns.boxplot(x=df_bc_all_f.index.year, y='Runoff(mm_day)', data= df_bc_all_f,hue = "Condition", showfliers=False)

# %%
ax = sns.boxplot(x=df_bc_u.index.month, y='Runoff(mm_day)', data= df_bc_u, hue = "Criteria", showfliers=False)

# %%
ax = sns.boxplot(x=df_bc_all_f.index.year, y='Runoff(mm_day)', data= df_bc_all_f, hue = "Run", showfliers=False)

# %%
ax = sns.boxplot(x=df_bc_all_f.index.year, y='NO3', data= df_bc_all_f, hue = "Run", showfliers=False)

# %%
ax = sns.boxplot(x=df_bc_all_f.index.year, y='NH4', data= df_bc_all_f, hue = "Run", showfliers=False)

# %%
ax = sns.boxplot(x=df_bc_all_f.index.year, y='DOC_mg/L', data= df_bc_all_f, hue = "Run", showfliers=False)

#'DOC_mg/L

# %%
ax = sns.boxplot(x=df_bc_all_f.index.year, y='pH', data= df_bc_all_f, hue = "Run", showfliers=False)

# %%
ax = sns.boxplot(x=df_bc_all_f.index.month, y='Temp ', data= df_bc_all_f, hue = "Run", showfliers=False)

# %%
df_bc_all_f.groupby(by=[df_bc_all_f.index.month, df_bc_all_f.index.year]).describe()
# Out:
#               pH                                                    \
#            count      mean       std       min  25%  50%  75%  max
# date date
# 1    2002  187.0  8.496043  0.054114  7.760000  8.5  8.5  8.5  8.5
#      2003  187.0  8.497798  0.027212  8.130000  8.5  8.5  8.5  8.5
#      2004  186.0  8.493518  0.032091  8.187190  8.5  8.5  8.5  8.5
#      2005  187.0  8.496684  0.045339  7.880000  8.5  8.5  8.5  8.5
#      2006  187.0  8.481590  0.076263  7.730000  8.5  8.5  8.5  8.5
# ...          ...       ...       ...       ...  ...  ...  ...  ...
# 12   2002  187.0  8.497701  0.031445  8.070000  8.5  8.5  8.5  8.5
#      2003  187.0  8.426563  0.165473  7.703715  8.5  8.5  8.5  8.5
#      2004  187.0  8.496471  0.048264  7.840000  8.5  8.5  8.5  8.5
#      2005  187.0  8.464655  0.086463  7.860000  8.5  8.5  8.5  8.5
#      2006  186.0  8.462986  0.090436  8.106440  8.5  8.5  8.5  8.5
#
#           Runoff(mm_day)            ...       NH4              NO3            \
# ...

# %%
g = sns.catplot(x="Criteria", col="Run", col_wrap=7,
                data=df_bc_all_f[df_bc_all_f.Run.notnull()],
                kind="count", height=3, aspect=.8, order={'Exceeds', 'Meets'})

# %%
g = sns.catplot(x="date", y="NO3",
               hue="Condition", row="Run",
               data=df_bc_all_f[df_bc_all_f.notnull()],
               orient="v", height=2, aspect=3, palette="Set3",
               kind="violin", dodge=True, cut=0, bw=.2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-96-8c614ea6ca86> in <module>
# ----> 1 g = sns.catplot(x="date", y="NO3",
#       2                hue="Condition", row="Run",
#       3                data=df_bc_all_f[df_bc_all_f.notnull()],
#       4                orient="v", height=2, aspect=3, palette="Set3",
#       5                kind="violin", dodge=True, cut=0, bw=.2)
#
# ~\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
fig, ax =plt.subplots(4, sharex=True)

sns.violinplot(x='Criteria', y='NH4_Pool', data=df_VA_A, hue='Run', figsize=(12,8), ax=ax[0], title="VELMA/NLDAS Compare Original Data", legend=False)
sns.violinplot(x='Criteria', y='NO3_Pool', figsize=(12,8), ax=ax[1], title="Down-sampled to 10-day periods",legend=False)
sns.violinplot(x='Criteria', y='DOC_Pool', figsize=(12,8), ax=ax[2], title="Down-sampled to 30-day periods",legend=False)
sns.violinplot(x='Criteria', y='pH_1T', figsize=(12,8), ax=ax[3], title="Down-sampled to 120-day periods",legend=False)

# %%
datetime_series_gt = pd.date_range('2001-08-02', periods=2344, freq ='D')
gt = 'y1_bc_discharge.csv'
df_gt =pd.read_csv(gt, dtype=None)
ts_gt = pd.Series(df_gt['0'].values[:], datetime_series_gt)
ts_gt[0:-366]
# Out:
# 2001-08-02    0.000000
# 2001-08-03    0.000000
# 2001-08-04    0.000000
# 2001-08-05    0.000000
# 2001-08-06    0.000000
#                 ...
# 2006-12-27    0.040719
# 2006-12-28    0.040719
# 2006-12-29    0.040719
# 2006-12-30    0.040719
# 2006-12-31    0.040719
# Freq: D, Length: 1978, dtype: float64

# %%
datetime_series_nldas = pd.date_range('1992-01-01', periods=10226, freq='D')
datetime_series_nldas
# Out:
# DatetimeIndex(['1992-01-01', '1992-01-02', '1992-01-03', '1992-01-04',
#                '1992-01-05', '1992-01-06', '1992-01-07', '1992-01-08',
#                '1992-01-09', '1992-01-10',
#                ...
#                '2019-12-21', '2019-12-22', '2019-12-23', '2019-12-24',
#                '2019-12-25', '2019-12-26', '2019-12-27', '2019-12-28',
#                '2019-12-29', '2019-12-30'],
#               dtype='datetime64[ns]', length=10226, freq='D')

# %%
ts_nldas = pd.Series(df_qobs['0'].values[:], datetime_series_nldas)
ts_nldas
# Out:
# 1992-01-01    0.077
# 1992-01-02    0.066
# 1992-01-03    0.203
# 1992-01-04    0.053
# 1992-01-05    0.158
#               ...
# 2019-12-26    0.034
# 2019-12-27    0.000
# 2019-12-28    0.000
# 2019-12-29    0.000
# 2019-12-30    0.000
# Freq: D, Length: 10226, dtype: float64

# %%
fig, ax =plt.subplots(4, sharex=True)

ts_nldas[2192:5479].plot(figsize=(12,8), ax=ax[0], title="NLDAS Original Data", legend=False)

ts_nldas[2192:5479].resample('10D').mean().plot(figsize=(12,8), ax=ax[1], title="Down-sampled to 10-day periods",legend=False)

ts_nldas[2192:5479].resample('30D').mean().plot(figsize=(12,8), ax=ax[2], title="Down-sampled to 30-day periods",legend=False)

ts_nldas[2192:5479].resample('120D').mean().plot(figsize=(12,8), ax=ax[3], title="Down-sampled to 120-day periods",legend=False)
# Out:
# <AxesSubplot:title={'center':'Down-sampled to 120-day periods'}>

# %%
#Creating Series for All VELMA simulation Runs discharge for timeseries analysis
ts_A1 = pd.Series(df_A1['Runoff_All(mm/day)_Delineated_Average'].values[:], datetime_series_nldas[3501:5479])
ts_A1
ts_A2 = pd.Series(df_A2['Runoff_All(mm/day)_Delineated_Average'].values[:], datetime_series_nldas[3501:5479])
ts_A3 = pd.Series(df_A3['Runoff_All(mm/day)_Delineated_Average'].values[:], datetime_series_nldas[3501:5479])
ts_B1 = pd.Series(df_B1['Runoff_All(mm/day)_Delineated_Average'].values[:], datetime_series_nldas[3501:5479])
ts_B2 = pd.Series(df_B2['Runoff_All(mm/day)_Delineated_Average'].values[:], datetime_series_nldas[3501:5479])
ts_B3 = pd.Series(df_B3['Runoff_All(mm/day)_Delineated_Average'].values[:], datetime_series_nldas[3501:5479])

# %%
fig, ax =plt.subplots(4, sharex=True)

ts_A1[:].plot(figsize=(12,8), ax=ax[0], title="VELMA/NLDAS Compare Original Data", legend=False)
ts_A1[:].resample('10D').mean().plot(figsize=(12,8), ax=ax[1], title="Down-sampled to 10-day periods",legend=False)
ts_A1[:].resample('30D').mean().plot(figsize=(12,8), ax=ax[2], title="Down-sampled to 30-day periods",legend=False)
ts_A1[:].resample('120D').mean().plot(figsize=(12,8), ax=ax[3], title="Down-sampled to 120-day periods",legend=False)

ts_B1[:].plot(figsize=(12,8), ax=ax[0])
ts_B1[:].resample('10D').mean().plot(figsize=(12,8), ax=ax[1], title="Down-sampled to 10-day periods",legend=False)
ts_B1[:].resample('30D').mean().plot(figsize=(12,8), ax=ax[2], title="Down-sampled to 30-day periods",legend=False)
ts_B1[:].resample('120D').mean().plot(figsize=(12,8), ax=ax[3], title="Down-sampled to 120-day periods",legend=False)


ts_A2[:].plot(figsize=(12,8), ax=ax[0])
ts_A2[:].resample('10D').mean().plot(figsize=(12,8), ax=ax[1], title="Down-sampled to 10-day periods",legend=False)
ts_A2[:].resample('30D').mean().plot(figsize=(12,8), ax=ax[2], title="Down-sampled to 30-day periods",legend=False)
ts_A2[:].resample('120D').mean().plot(figsize=(12,8), ax=ax[3], title="Down-sampled to 120-day periods",legend=False)

ts_B2[:].plot(figsize=(12,8), ax=ax[0])
ts_B2[:].resample('10D').mean().plot(figsize=(12,8), ax=ax[1], title="Down-sampled to 10-day periods",legend=False)
ts_B2[:].resample('30D').mean().plot(figsize=(12,8), ax=ax[2], title="Down-sampled to 30-day periods",legend=False)
ts_B2[:].resample('120D').mean().plot(figsize=(12,8), ax=ax[3], title="Down-sampled to 120-day periods",legend=False)



#ts_A3[:].plot(figsize=(12,8), ax=ax[0])
#ts_A3[:].resample('10D').mean().plot(figsize=(12,8), ax=ax[1], title="Down-sampled to 10-day periods",legend=False)
#ts_A3[:].resample('30D').mean().plot(figsize=(12,8), ax=ax[2], title="Down-sampled to 30-day periods",legend=False)
#ts_A3[:].resample('120D').mean().plot(figsize=(12,8), ax=ax[3], title="Down-sampled to 120-day periods",legend=False)


ts_nldas[3501:5479].plot(figsize=(12,8), ax=ax[0])

ts_nldas[3501:5479].resample('10D').mean().plot(figsize=(12,8), ax=ax[1], title="Down-sampled to 10-day periods",legend=False)

ts_nldas[3501:5479].resample('30D').mean().plot(figsize=(12,8), ax=ax[2], title="Down-sampled to 30-day periods",legend=False)

ts_nldas[3501:5479].resample('120D').mean().plot(figsize=(12,8), ax=ax[3], title="Down-sampled to 120-day periods",legend=False)

ts_gt[0:-366].plot(figsize=(12,8), ax=ax[0])
ts_gt[0:-366].resample('10D').mean().plot(figsize=(12,8), ax=ax[1], title="Down-sampled to 10-day periods",legend=False)
ts_gt[0:-366].resample('30D').mean().plot(figsize=(12,8), ax=ax[2], title="Down-sampled to 30-day periods",legend=False)
ts_gt[0:-366].resample('120D').mean().plot(figsize=(12,8), ax=ax[3], title="Down-sampled to 120-day periods",legend=False)

plt.legend(('A1', 'B1', 'A2', 'B2', 'NLDAS', 'GT'), loc='best')
ax=plt.gca(); plt.ylabel('Runoff (mm_day)'); plt.xlabel('Year');

# %%
fig, ax =plt.subplots(4, sharex=True)

ts_B1[:].plot(figsize=(12,8), ax=ax[0], title="VELMA/NLDAS Compare Original Data", legend=False)
ts_B1[:].resample('10D').mean().plot(figsize=(12,8), ax=ax[1], title="Down-sampled to 10-day periods",legend=False)
ts_B1[:].resample('30D').mean().plot(figsize=(12,8), ax=ax[2], title="Down-sampled to 30-day periods",legend=False)
ts_B1[:].resample('120D').mean().plot(figsize=(12,8), ax=ax[3], title="Down-sampled to 120-day periods",legend=False)

ts_B2[:].plot(figsize=(12,8), ax=ax[0])
ts_B2[:].resample('10D').mean().plot(figsize=(12,8), ax=ax[1], title="Down-sampled to 10-day periods",legend=False)
ts_B2[:].resample('30D').mean().plot(figsize=(12,8), ax=ax[2], title="Down-sampled to 30-day periods",legend=False)
ts_B2[:].resample('120D').mean().plot(figsize=(12,8), ax=ax[3], title="Down-sampled to 120-day periods",legend=False)

#ts_A3[:].plot(figsize=(12,8), ax=ax[0])
#ts_A3[:].resample('10D').mean().plot(figsize=(12,8), ax=ax[1], title="Down-sampled to 10-day periods",legend=False)
#ts_A3[:].resample('30D').mean().plot(figsize=(12,8), ax=ax[2], title="Down-sampled to 30-day periods",legend=False)
#ts_A3[:].resample('120D').mean().plot(figsize=(12,8), ax=ax[3], title="Down-sampled to 120-day periods",legend=False)


ts_nldas[3501:5479].plot(figsize=(12,8), ax=ax[0])

ts_nldas[3501:5479].resample('10D').mean().plot(figsize=(12,8), ax=ax[1], title="Down-sampled to 10-day periods",legend=False)

ts_nldas[3501:5479].resample('30D').mean().plot(figsize=(12,8), ax=ax[2], title="Down-sampled to 30-day periods",legend=False)

ts_nldas[3501:5479].resample('120D').mean().plot(figsize=(12,8), ax=ax[3], title="Down-sampled to 120-day periods",legend=False)

ts_gt[0:-366].plot(figsize=(12,8), ax=ax[0])
ts_gt[0:-366].resample('10D').mean().plot(figsize=(12,8), ax=ax[1], title="Down-sampled to 10-day periods",legend=False)
ts_gt[0:-366].resample('30D').mean().plot(figsize=(12,8), ax=ax[2], title="Down-sampled to 30-day periods",legend=False)
ts_gt[0:-366].resample('120D').mean().plot(figsize=(12,8), ax=ax[3], title="Down-sampled to 120-day periods",legend=False)

plt.legend(('B1', 'B2', 'NLDAS', 'GT'), loc='best')

# %%
#plt.show();plt.xlabel('Steps (in number of Days)'); plt.ylabel('Runoff_All(mm/day)_Delineated_Average'); plt.title('Brush Creek 20APR21a Runoff_All(mm/day)_Delineated_Average 01 - 06'); plt.plot(df_qmod['Step'][1309:3288], df_qmod['Runoff_All(mm/day)_Delineated_Average'][1309:3288], linewidth = 1); plt.plot(df_qmod['Step'][1309:3288], df_qobs[3501:5479], linewidth = 1); ax=plt.gca(); ax.set_ylim([-0.25,5]); plt.legend(('VELMA', 'NLDAS'), loc='best');
